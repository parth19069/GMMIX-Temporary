# %%
import pandas as pd

df_tweet = pd.read_csv('sorted_tweet_data_full.csv', low_memory=False)
df_tweet['tweet_id'] = df_tweet['tweet_id'].apply(lambda x: int(x))
df_tweet
# Out:
#            s_no                   datetime             tweet_id  \
# 0       1038860  2021-07-21 12:22:28+00:00  1417822283087876096
# 1       1038859  2021-07-22 00:02:32+00:00  1417998459785916416
# 2       1038858  2021-07-22 14:58:05+00:00  1418223832540778496
# 3       1038854  2021-07-23 00:52:51+00:00  1418373507755425792
# 4       1038853  2021-07-24 00:25:38+00:00  1418729048730050560
# ...         ...                        ...                  ...
# 245023   722284  2021-12-31 00:51:50+00:00  1476717701838282752
# 245024   722282  2021-12-31 01:56:55+00:00  1476734080112738304
# 245025   722281  2021-12-31 07:00:07+00:00  1476810380433190912
# 245026   722279  2021-12-31 08:00:08+00:00  1476825483459194880
# 245027   722278  2021-12-31 08:30:01+00:00  1476833007579189248
#
#         retweet_count  like_count         project  polarity  \
# 0                 0.0         5.0       0N1 Force  0.000000
# 1                56.0       163.0       0N1 Force  0.453153
# ...
